# %%
# Import dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# Import dependencies
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///Resources/hawaii.sqlite")
conn = engine.connect()

# %%
# reflect an existing database into a new model
Base = automap_base()
inspector = inspect(engine)

# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
print(Base.classes.keys())
print(inspector.get_table_names())
# Out:
# ['measurement', 'station']
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# View columns in Measurement table
columns = inspector.get_columns('measurement')
for each in columns:
    print(each["name"], each["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# View columns in Station table
columns = inspector.get_columns('station')
for each in columns:
    print(each["name"], each["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
most_recent = session.query(Measurement).order_by(Measurement.date.desc()).first()
print(most_recent.date)
# Out:
# 2017-08-23

# %% [markdown]
# all_m = session.query(Measurement).order_by(Measurement.date.desc())
# for row in all_m:
#     print(row.date, row.station, row.prcp)
#
# # ***cell not required

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# Starting from the most recent data point in the database. 

# prior_12 = session.query(Measurement).filter(Measurement.date >= 2016-08-23)

# date = dt.datetime(2016, 8, 23)

results = session.query(Measurement.date, Measurement.prcp).\
                  filter(Measurement.date > dt.datetime(2016, 8, 23)).order_by(Measurement.date.desc())

# List comprehension solution
prior12_rows = [{"Date": result[0], "Precipitation": result[1]} for result in results]
print(len(prior12_rows))
prior12_rows
# Out:
# 2223
# [{'Date': '2017-08-23', 'Precipitation': 0.0},
#  {'Date': '2017-08-23', 'Precipitation': 0.0},
#  {'Date': '2017-08-23', 'Precipitation': 2.0},
#  {'Date': '2017-08-23', 'Precipitation': 11.4},
#  {'Date': '2017-08-22', 'Precipitation': 0.0},
#  {'Date': '2017-08-22', 'Precipitation': 0.0},
#  {'Date': '2017-08-22', 'Precipitation': 12.7},
#  {'Date': '2017-08-21', 'Precipitation': 0.0},
#  {'Date': '2017-08-21', 'Precipitation': 0.5},
#  {'Date': '2017-08-21', 'Precipitation': None},
#  {'Date': '2017-08-21', 'Precipitation': 14.2},
#  {'Date': '2017-08-20', 'Precipitation': 0.0},
#  {'Date': '2017-08-20', 'Precipitation': 0.3},
#  {'Date': '2017-08-20', 'Precipitation': None},
#  {'Date': '2017-08-19', 'Precipitation': 0.0},
#  {'Date': '2017-08-19', 'Precipitation': 0.0},
#  {'Date': '2017-08-19', 'Precipitation': None},
#  {'Date': '2017-08-19', 'Precipitation': 2.3},
#  {'Date': '2017-08-18', 'Precipitation': 0.0},
#  {'Date': '2017-08-18', 'Precipitation': 0.0},
#  {'Date': '2017-08-18', 'Precipitation': 1.5},
#  {'Date': '2017-08-18', 'Precipitation': None},
#  {'Date': '2017-08-17', 'Precipitation': 0.0},
#  {'Date': '2017-08-17', 'Precipitation': 1.3},
#  {'Date': '2017-08-17', 'Precipitation': 0.3},
#  {'Date': '2017-08-17', 'Precipitation': 3.3},
#  {'Date': '2017-08-16', 'Precipitation': 0.0},
#  {'Date': '2017-08-16', 'Precipitation': 1.8},
#  {'Date': '2017-08-16', 'Precipitation': 3.0},
#  {'Date': '2017-08-16', 'Precipitation': 10.7},
#  {'Date': '2017-08-15', 'Precipitation': 0.5},
#  {'Date': '2017-08-15', 'Precipitation': 0.0},
#  {'Date': '2017-08-15', 'Precipitation': 1.5},
#  {'Date': '2017-08-15', 'Precipitation': 8.1},
#  {'Date': '2017-08-15', 'Precipitation': 10.7},
#  {'Date': '2017-08-14', 'Precipitation': 0.0},
#  {'Date': '2017-08-14', 'Precipitation': 0.3},
#  {'Date': '2017-08-14', 'Precipitation': 2.0},
#  {'Date': '2017-08-14', 'Precipitation': 0.0},
#  {'Date': '2017-08-14', 'Precipitation': 5.6},
#  {'Date': '2017-08-13', 'Precipitation': 0.0},
#  {'Date': '2017-08-13', 'Precipitation': None},
#  {'Date': '2017-08-13', 'Precipitation': 0.0},
#  {'Date': '2017-08-13', 'Precipitation': 0.0},
#  {'Date': '2017-08-13', 'Precipitation': None},
#  {'Date': '2017-08-12', 'Precipitation': 0.0},
#  {'Date': '2017-08-12', 'Precipitation': 0.0},
#  {'Date': '2017-08-12', 'Precipitation': 3.6},
#  {'Date': '2017-08-11', 'Precipitation': 0.0},
#  {'Date': '2017-08-11', 'Precipitation': 0.0},
#  {'Date': '2017-08-11', 'Precipitation': 0.0},
#  {'Date': '2017-08-11', 'Precipitation': None},
#  {'Date': '2017-08-10', 'Precipitation': 0.0},
#  {'Date': '2017-08-10', 'Precipitation': 0.0},
#  {'Date': '2017-08-10', 'Precipitation': 0.0},
#  {'Date': '2017-08-10', 'Precipitation': 1.8},
#  {'Date': '2017-08-09', 'Precipitation': 0.0},
#  {'Date': '2017-08-09', 'Precipitation': 0.0},
#  {'Date': '2017-08-09', 'Precipitation': 3.8},
#  {'Date': '2017-08-08', 'Precipitation': 0.0},
#  {'Date': '2017-08-08', 'Precipitation': 2.5},
#  {'Date': '2017-08-08', 'Precipitation': 0.0},
#  {'Date': '2017-08-08', 'Precipitation': 8.6},
#  {'Date': '2017-08-07', 'Precipitation': 0.0},
#  {'Date': '2017-08-07', 'Precipitation': 0.0},
#  {'Date': '2017-08-07', 'Precipitation': 0.0},
#  {'Date': '2017-08-07', 'Precipitation': 1.3},
#  {'Date': '2017-08-06', 'Precipitation': 0.0},
#  {'Date': '2017-08-06', 'Precipitation': 0.0},
#  {'Date': '2017-08-06', 'Precipitation': 0.0},
#  {'Date': '2017-08-06', 'Precipitation': 0.0},
#  {'Date': '2017-08-06', 'Precipitation': None},
#  {'Date': '2017-08-05', 'Precipitation': 0.0},
#  {'Date': '2017-08-05', 'Precipitation': 1.5},
#  {'Date': '2017-08-05', 'Precipitation': None},
#  {'Date': '2017-08-04', 'Precipitation': 0.5},
#  {'Date': '2017-08-04', 'Precipitation': 1.0},
#  {'Date': '2017-08-04', 'Precipitation': 0.0},
#  {'Date': '2017-08-04', 'Precipitation': 0.0},
#  {'Date': '2017-08-03', 'Precipitation': 0.0},
#  {'Date': '2017-08-03', 'Precipitation': 0.3},
#  {'Date': '2017-08-03', 'Precipitation': 0.0},
#  {'Date': '2017-08-03', 'Precipitation': 1.5},
#  {'Date': '2017-08-02', 'Precipitation': 0.0},
#  {'Date': '2017-08-02', 'Precipitation': 1.3},
#  {'Date': '2017-08-02', 'Precipitation': 0.0},
#  {'Date': '2017-08-02', 'Precipitation': 6.4},
#  {'Date': '2017-08-01', 'Precipitation': 0.5},
#  {'Date': '2017-08-01', 'Precipitation': 3.0},
#  {'Date': '2017-08-01', 'Precipitation': 0.0},
#  {'Date': '2017-08-01', 'Precipitation': None},
#  {'Date': '2017-07-31', 'Precipitation': 0.0},
#  {'Date': '2017-07-31', 'Precipitation': 0.0},
#  {'Date': '2017-07-31', 'Precipitation': None},
#  {'Date': '2017-07-31', 'Precipitation': None},
#  {'Date': '2017-07-31', 'Precipitation': 0.0},
#  {'Date': '2017-07-31', 'Precipitation': 0.0},
#  {'Date': '2017-07-31', 'Precipitation': 0.0},
#  {'Date': '2017-07-30', 'Precipitation': 0.0},
#  {'Date': '2017-07-30', 'Precipitation': 0.0},
#  {'Date': '2017-07-30', 'Precipitation': 0.0},
#  {'Date': '2017-07-30', 'Precipitation': 0.0},
#  {'Date': '2017-07-30', 'Precipitation': 7.6},
#  {'Date': '2017-07-29', 'Precipitation': 0.0},
#  {'Date': '2017-07-29', 'Precipitation': 1.5},
#  {'Date': '2017-07-29', 'Precipitation': 0.5},
#  {'Date': '2017-07-29', 'Precipitation': 0.0},
#  {'Date': '2017-07-29', 'Precipitation': 5.8},
#  {'Date': '2017-07-29', 'Precipitation': 7.6},
#  {'Date': '2017-07-28', 'Precipitation': 0.0},
#  {'Date': '2017-07-28', 'Precipitation': 3.3},
#  {'Date': '2017-07-28', 'Precipitation': 3.6},
#  {'Date': '2017-07-28', 'Precipitation': 0.3},
#  {'Date': '2017-07-28', 'Precipitation': 0.0},
#  {'Date': '2017-07-28', 'Precipitation': 2.3},
#  {'Date': '2017-07-28', 'Precipitation': 10.2},
#  {'Date': '2017-07-27', 'Precipitation': 0.0},
#  {'Date': '2017-07-27', 'Precipitation': 0.0},
#  {'Date': '2017-07-27', 'Precipitation': 0.0},
#  {'Date': '2017-07-27', 'Precipitation': None},
#  {'Date': '2017-07-27', 'Precipitation': 0.0},
#  {'Date': '2017-07-27', 'Precipitation': 0.3},
#  {'Date': '2017-07-27', 'Precipitation': 0.0},
#  {'Date': '2017-07-26', 'Precipitation': 0.0},
#  {'Date': '2017-07-26', 'Precipitation': 1.5},
#  {'Date': '2017-07-26', 'Precipitation': 0.5},
#  {'Date': '2017-07-26', 'Precipitation': None},
#  {'Date': '2017-07-26', 'Precipitation': 0.0},
#  {'Date': '2017-07-26', 'Precipitation': 3.0},
#  {'Date': '2017-07-26', 'Precipitation': 7.6},
#  {'Date': '2017-07-25', 'Precipitation': 0.0},
#  {'Date': '2017-07-25', 'Precipitation': 0.8},
#  {'Date': '2017-07-25', 'Precipitation': 3.0},
#  {'Date': '2017-07-25', 'Precipitation': 0.0},
#  {'Date': '2017-07-25', 'Precipitation': 1.3},
#  {'Date': '2017-07-25', 'Precipitation': 2.8},
#  {'Date': '2017-07-25', 'Precipitation': 7.6},
#  {'Date': '2017-07-24', 'Precipitation': 1.3},
#  {'Date': '2017-07-24', 'Precipitation': 14.7},
#  {'Date': '2017-07-24', 'Precipitation': 30.2},
#  {'Date': '2017-07-24', 'Precipitation': None},
#  {'Date': '2017-07-24', 'Precipitation': 15.5},
#  {'Date': '2017-07-24', 'Precipitation': 21.3},
#  {'Date': '2017-07-23', 'Precipitation': 0.0},
#  {'Date': '2017-07-23', 'Precipitation': 1.5},
#  {'Date': '2017-07-23', 'Precipitation': 1.8},
#  {'Date': '2017-07-23', 'Precipitation': 5.1},
#  {'Date': '2017-07-23', 'Precipitation': 20.3},
#  {'Date': '2017-07-22', 'Precipitation': 0.8},
#  {'Date': '2017-07-22', 'Precipitation': 1.8},
#  {'Date': '2017-07-22', 'Precipitation': 3.0},
#  {'Date': '2017-07-22', 'Precipitation': 0.0},
#  {'Date': '2017-07-22', 'Precipitation': 5.1},
#  {'Date': '2017-07-22', 'Precipitation': 101.6},
#  {'Date': '2017-07-21', 'Precipitation': 0.0},
#  {'Date': '2017-07-21', 'Precipitation': 0.0},
#  {'Date': '2017-07-21', 'Precipitation': 0.0},
#  {'Date': '2017-07-21', 'Precipitation': 0.0},
#  {'Date': '2017-07-21', 'Precipitation': 0.0},
#  {'Date': '2017-07-21', 'Precipitation': 0.8},
#  {'Date': '2017-07-21', 'Precipitation': 2.5},
#  {'Date': '2017-07-20', 'Precipitation': 0.8},
#  {'Date': '2017-07-20', 'Precipitation': 3.0},
#  {'Date': '2017-07-20', 'Precipitation': 0.0},
#  {'Date': '2017-07-20', 'Precipitation': 0.0},
#  {'Date': '2017-07-20', 'Precipitation': 8.4},
#  {'Date': '2017-07-20', 'Precipitation': 1.5},
#  {'Date': '2017-07-20', 'Precipitation': 17.8},
#  {'Date': '2017-07-19', 'Precipitation': 0.0},
#  {'Date': '2017-07-19', 'Precipitation': 2.3},
#  {'Date': '2017-07-19', 'Precipitation': 0.0},
#  {'Date': '2017-07-19', 'Precipitation': 0.0},
#  {'Date': '2017-07-19', 'Precipitation': 1.3},
#  {'Date': '2017-07-19', 'Precipitation': 6.9},
#  {'Date': '2017-07-18', 'Precipitation': 1.3},
#  {'Date': '2017-07-18', 'Precipitation': 0.8},
#  {'Date': '2017-07-18', 'Precipitation': 0.0},
#  {'Date': '2017-07-18', 'Precipitation': 0.0},
#  {'Date': '2017-07-18', 'Precipitation': 0.0},
#  {'Date': '2017-07-18', 'Precipitation': 1.3},
#  {'Date': '2017-07-18', 'Precipitation': 61.0},
#  {'Date': '2017-07-17', 'Precipitation': 0.8},
#  {'Date': '2017-07-17', 'Precipitation': 3.0},
#  {'Date': '2017-07-17', 'Precipitation': 4.1},
#  {'Date': '2017-07-17', 'Precipitation': 0.0},
#  {'Date': '2017-07-17', 'Precipitation': 5.3},
#  {'Date': '2017-07-17', 'Precipitation': 9.9},
#  {'Date': '2017-07-16', 'Precipitation': 0.5},
#  {'Date': '2017-07-16', 'Precipitation': 1.8},
#  {'Date': '2017-07-16', 'Precipitation': 3.0},
#  {'Date': '2017-07-16', 'Precipitation': 0.0},
#  {'Date': '2017-07-16', 'Precipitation': 2.5},
#  {'Date': '2017-07-16', 'Precipitation': 12.7},
#  {'Date': '2017-07-15', 'Precipitation': 0.0},
#  {'Date': '2017-07-15', 'Precipitation': 0.8},
#  {'Date': '2017-07-15', 'Precipitation': 0.3},
#  {'Date': '2017-07-15', 'Precipitation': 0.0},
#  {'Date': '2017-07-15', 'Precipitation': 1.3},
#  {'Date': '2017-07-15', 'Precipitation': 2.5},
#  {'Date': '2017-07-14', 'Precipitation': 0.5},
#  {'Date': '2017-07-14', 'Precipitation': 1.3},
#  {'Date': '2017-07-14', 'Precipitation': 0.0},
#  {'Date': '2017-07-14', 'Precipitation': 0.0},
#  {'Date': '2017-07-14', 'Precipitation': 5.1},
#  {'Date': '2017-07-14', 'Precipitation': 17.3},
#  {'Date': '2017-07-13', 'Precipitation': 1.8},
#  {'Date': '2017-07-13', 'Precipitation': 8.4},
#  {'Date': '2017-07-13', 'Precipitation': 7.6},
#  {'Date': '2017-07-13', 'Precipitation': None},
#  {'Date': '2017-07-13', 'Precipitation': 2.8},
#  {'Date': '2017-07-13', 'Precipitation': 8.1},
#  {'Date': '2017-07-13', 'Precipitation': 17.3},
#  {'Date': '2017-07-12', 'Precipitation': 0.0},
#  {'Date': '2017-07-12', 'Precipitation': 0.3},
#  {'Date': '2017-07-12', 'Precipitation': 0.5},
#  {'Date': '2017-07-12', 'Precipitation': None},
#  {'Date': '2017-07-12', 'Precipitation': 0.0},
#  {'Date': '2017-07-12', 'Precipitation': 7.1},
#  {'Date': '2017-07-12', 'Precipitation': 1.3},
#  {'Date': '2017-07-11', 'Precipitation': 0.0},
#  {'Date': '2017-07-11', 'Precipitation': 0.3},
#  {'Date': '2017-07-11', 'Precipitation': 0.0},
#  {'Date': '2017-07-11', 'Precipitation': None},
#  {'Date': '2017-07-11', 'Precipitation': 0.0},
#  {'Date': '2017-07-11', 'Precipitation': 0.5},
#  {'Date': '2017-07-11', 'Precipitation': 0.0},
#  {'Date': '2017-07-10', 'Precipitation': 0.0},
#  {'Date': '2017-07-10', 'Precipitation': 0.0},
#  {'Date': '2017-07-10', 'Precipitation': 0.0},
#  {'Date': '2017-07-10', 'Precipitation': None},
#  {'Date': '2017-07-10', 'Precipitation': 0.0},
#  {'Date': '2017-07-10', 'Precipitation': 0.5},
#  {'Date': '2017-07-10', 'Precipitation': 0.5},
#  {'Date': '2017-07-09', 'Precipitation': 0.0},
#  {'Date': '2017-07-09', 'Precipitation': 2.3},
#  {'Date': '2017-07-09', 'Precipitation': 0.0},
#  {'Date': '2017-07-09', 'Precipitation': 0.0},
#  {'Date': '2017-07-09', 'Precipitation': 2.8},
#  {'Date': '2017-07-09', 'Precipitation': 0.0},
#  {'Date': '2017-07-08', 'Precipitation': 0.0},
#  {'Date': '2017-07-08', 'Precipitation': 0.5},
#  {'Date': '2017-07-08', 'Precipitation': 1.5},
#  {'Date': '2017-07-08', 'Precipitation': 0.0},
#  {'Date': '2017-07-08', 'Precipitation': 0.0},
#  {'Date': '2017-07-08', 'Precipitation': 0.5},
#  {'Date': '2017-07-07', 'Precipitation': 0.0},
#  {'Date': '2017-07-07', 'Precipitation': 0.5},
#  {'Date': '2017-07-07', 'Precipitation': None},
#  {'Date': '2017-07-07', 'Precipitation': None},
#  {'Date': '2017-07-07', 'Precipitation': 0.0},
#  {'Date': '2017-07-07', 'Precipitation': 4.6},
#  {'Date': '2017-07-07', 'Precipitation': 7.6},
#  {'Date': '2017-07-06', 'Precipitation': 0.0},
#  {'Date': '2017-07-06', 'Precipitation': 0.0},
#  {'Date': '2017-07-06', 'Precipitation': None},
#  {'Date': '2017-07-06', 'Precipitation': 0.0},
#  {'Date': '2017-07-06', 'Precipitation': 0.0},
#  {'Date': '2017-07-06', 'Precipitation': 0.5},
#  {'Date': '2017-07-05', 'Precipitation': 0.0},
#  {'Date': '2017-07-05', 'Precipitation': 0.0},
#  {'Date': '2017-07-05', 'Precipitation': None},
#  {'Date': '2017-07-05', 'Precipitation': None},
#  {'Date': '2017-07-05', 'Precipitation': None},
#  {'Date': '2017-07-05', 'Precipitation': 0.0},
#  {'Date': '2017-07-05', 'Precipitation': 0.0},
#  {'Date': '2017-07-04', 'Precipitation': 1.0},
#  {'Date': '2017-07-04', 'Precipitation': 0.8},
#  {'Date': '2017-07-04', 'Precipitation': 2.0},
#  {'Date': '2017-07-04', 'Precipitation': 0.0},
#  {'Date': '2017-07-03', 'Precipitation': 1.0},
#  {'Date': '2017-07-03', 'Precipitation': 3.3},
#  {'Date': '2017-07-03', 'Precipitation': None},
#  {'Date': '2017-07-03', 'Precipitation': None},
#  {'Date': '2017-07-03', 'Precipitation': 0.5},
#  {'Date': '2017-07-03', 'Precipitation': 3.8},
#  {'Date': '2017-07-03', 'Precipitation': 10.2},
#  {'Date': '2017-07-02', 'Precipitation': 0.5},
#  {'Date': '2017-07-02', 'Precipitation': 1.3},
#  {'Date': '2017-07-02', 'Precipitation': None},
#  {'Date': '2017-07-02', 'Precipitation': 3.8},
#  {'Date': '2017-07-02', 'Precipitation': 12.7},
#  {'Date': '2017-07-01', 'Precipitation': 0.5},
#  {'Date': '2017-07-01', 'Precipitation': 1.5},
#  {'Date': '2017-07-01', 'Precipitation': 2.0},
#  {'Date': '2017-07-01', 'Precipitation': 2.5},
#  {'Date': '2017-06-30', 'Precipitation': 2.0},
#  {'Date': '2017-06-30', 'Precipitation': 1.0},
#  {'Date': '2017-06-30', 'Precipitation': 0.0},
#  {'Date': '2017-06-30', 'Precipitation': 3.0},
#  {'Date': '2017-06-30', 'Precipitation': 1.8},
#  {'Date': '2017-06-30', 'Precipitation': 0.3},
#  {'Date': '2017-06-30', 'Precipitation': 5.1},
#  {'Date': '2017-06-29', 'Precipitation': 0.0},
#  {'Date': '2017-06-29', 'Precipitation': 0.8},
#  {'Date': '2017-06-29', 'Precipitation': None},
#  {'Date': '2017-06-29', 'Precipitation': 0.0},
#  {'Date': '2017-06-29', 'Precipitation': 0.0},
#  {'Date': '2017-06-29', 'Precipitation': 0.0},
#  {'Date': '2017-06-29', 'Precipitation': 1.0},
#  {'Date': '2017-06-28', 'Precipitation': 0.0},
#  {'Date': '2017-06-28', 'Precipitation': 0.3},
#  {'Date': '2017-06-28', 'Precipitation': 0.0},
#  {'Date': '2017-06-28', 'Precipitation': 0.0},
#  {'Date': '2017-06-28', 'Precipitation': 0.0},
#  {'Date': '2017-06-28', 'Precipitation': 0.5},
#  {'Date': '2017-06-27', 'Precipitation': 0.0},
#  {'Date': '2017-06-27', 'Precipitation': 0.0},
#  {'Date': '2017-06-27', 'Precipitation': 0.0},
#  {'Date': '2017-06-27', 'Precipitation': 0.0},
#  {'Date': '2017-06-27', 'Precipitation': 0.3},
#  {'Date': '2017-06-27', 'Precipitation': 2.5},
#  {'Date': '2017-06-26', 'Precipitation': 0.0},
#  {'Date': '2017-06-26', 'Precipitation': 0.5},
#  {'Date': '2017-06-26', 'Precipitation': None},
#  {'Date': '2017-06-26', 'Precipitation': None},
#  {'Date': '2017-06-26', 'Precipitation': 0.0},
#  {'Date': '2017-06-26', 'Precipitation': 1.5},
#  {'Date': '2017-06-26', 'Precipitation': 0.5},
#  {'Date': '2017-06-25', 'Precipitation': 0.0},
#  {'Date': '2017-06-25', 'Precipitation': 2.0},
#  {'Date': '2017-06-25', 'Precipitation': 0.0},
#  {'Date': '2017-06-25', 'Precipitation': 0.5},
#  {'Date': '2017-06-25', 'Precipitation': 12.7},
#  {'Date': '2017-06-24', 'Precipitation': 1.5},
#  {'Date': '2017-06-24', 'Precipitation': 0.0},
#  {'Date': '2017-06-24', 'Precipitation': 0.0},
#  {'Date': '2017-06-24', 'Precipitation': 9.1},
#  {'Date': '2017-06-24', 'Precipitation': 5.6},
#  {'Date': '2017-06-23', 'Precipitation': 0.0},
#  {'Date': '2017-06-23', 'Precipitation': 0.0},
#  {'Date': '2017-06-23', 'Precipitation': None},
#  {'Date': '2017-06-23', 'Precipitation': 0.0},
#  {'Date': '2017-06-23', 'Precipitation': 1.3},
#  {'Date': '2017-06-23', 'Precipitation': 3.0},
#  {'Date': '2017-06-23', 'Precipitation': 12.7},
#  {'Date': '2017-06-22', 'Precipitation': 0.0},
#  {'Date': '2017-06-22', 'Precipitation': 2.5},
#  {'Date': '2017-06-22', 'Precipitation': 0.0},
#  {'Date': '2017-06-22', 'Precipitation': 0.0},
#  {'Date': '2017-06-22', 'Precipitation': 1.5},
#  {'Date': '2017-06-22', 'Precipitation': 7.1},
#  {'Date': '2017-06-21', 'Precipitation': 0.0},
#  {'Date': '2017-06-21', 'Precipitation': 0.5},
#  {'Date': '2017-06-21', 'Precipitation': None},
#  {'Date': '2017-06-21', 'Precipitation': None},
#  {'Date': '2017-06-21', 'Precipitation': 4.8},
#  {'Date': '2017-06-21', 'Precipitation': 7.6},
#  {'Date': '2017-06-20', 'Precipitation': 0.5},
#  {'Date': '2017-06-20', 'Precipitation': 1.3},
#  {'Date': '2017-06-20', 'Precipitation': 4.3},
#  {'Date': '2017-06-20', 'Precipitation': None},
#  {'Date': '2017-06-20', 'Precipitation': 0.0},
#  {'Date': '2017-06-20', 'Precipitation': 7.9},
#  {'Date': '2017-06-19', 'Precipitation': 0.0},
#  {'Date': '2017-06-19', 'Precipitation': 1.3},
#  {'Date': '2017-06-19', 'Precipitation': 4.8},
#  {'Date': '2017-06-19', 'Precipitation': None},
#  {'Date': '2017-06-19', 'Precipitation': 0.3},
#  {'Date': '2017-06-19', 'Precipitation': 2.0},
#  {'Date': '2017-06-19', 'Precipitation': 10.2},
#  {'Date': '2017-06-18', 'Precipitation': 1.3},
#  {'Date': '2017-06-18', 'Precipitation': 6.4},
#  {'Date': '2017-06-18', 'Precipitation': 4.6},
#  {'Date': '2017-06-18', 'Precipitation': 0.0},
#  {'Date': '2017-06-18', 'Precipitation': 6.1},
#  {'Date': '2017-06-18', 'Precipitation': 17.8},
#  {'Date': '2017-06-17', 'Precipitation': 0.0},
#  {'Date': '2017-06-17', 'Precipitation': 8.9},
#  {'Date': '2017-06-17', 'Precipitation': 0.5},
#  {'Date': '2017-06-17', 'Precipitation': 0.0},
#  {'Date': '2017-06-17', 'Precipitation': 1.8},
#  {'Date': '2017-06-17', 'Precipitation': 2.5},
#  {'Date': '2017-06-16', 'Precipitation': 0.0},
#  {'Date': '2017-06-16', 'Precipitation': 0.5},
#  {'Date': '2017-06-16', 'Precipitation': 0.5},
#  {'Date': '2017-06-16', 'Precipitation': None},
#  {'Date': '2017-06-16', 'Precipitation': 0.0},
#  {'Date': '2017-06-16', 'Precipitation': 1.5},
#  {'Date': '2017-06-16', 'Precipitation': 2.5},
#  {'Date': '2017-06-15', 'Precipitation': 0.0},
#  {'Date': '2017-06-15', 'Precipitation': 4.3},
#  {'Date': '2017-06-15', 'Precipitation': 7.6},
#  {'Date': '2017-06-15', 'Precipitation': None},
#  {'Date': '2017-06-15', 'Precipitation': 0.0},
#  {'Date': '2017-06-15', 'Precipitation': 14.0},
#  {'Date': '2017-06-15', 'Precipitation': 42.9},
#  {'Date': '2017-06-14', 'Precipitation': 0.0},
#  {'Date': '2017-06-14', 'Precipitation': 6.9},
#  {'Date': '2017-06-14', 'Precipitation': 5.3},
#  {'Date': '2017-06-14', 'Precipitation': None},
#  {'Date': '2017-06-14', 'Precipitation': 1.5},
#  {'Date': '2017-06-14', 'Precipitation': 5.6},
#  {'Date': '2017-06-14', 'Precipitation': 20.6},
#  {'Date': '2017-06-13', 'Precipitation': 0.0},
#  {'Date': '2017-06-13', 'Precipitation': 9.1},
#  {'Date': '2017-06-13', 'Precipitation': 2.5},
#  {'Date': '2017-06-13', 'Precipitation': None},
#  {'Date': '2017-06-13', 'Precipitation': 0.8},
#  {'Date': '2017-06-13', 'Precipitation': 6.1},
#  {'Date': '2017-06-13', 'Precipitation': 16.5},
#  {'Date': '2017-06-12', 'Precipitation': 0.5},
#  {'Date': '2017-06-12', 'Precipitation': 4.8},
#  {'Date': '2017-06-12', 'Precipitation': 8.9},
#  {'Date': '2017-06-12', 'Precipitation': 3.6},
#  {'Date': '2017-06-12', 'Precipitation': 6.1},
#  {'Date': '2017-06-12', 'Precipitation': 20.6},
#  {'Date': '2017-06-11', 'Precipitation': 2.0},
#  {'Date': '2017-06-11', 'Precipitation': 6.1},
#  {'Date': '2017-06-11', 'Precipitation': 3.6},
#  {'Date': '2017-06-11', 'Precipitation': 6.4},
#  {'Date': '2017-06-11', 'Precipitation': 18.8},
#  {'Date': '2017-06-11', 'Precipitation': 17.8},
#  {'Date': '2017-06-10', 'Precipitation': 1.0},
#  {'Date': '2017-06-10', 'Precipitation': 5.3},
#  {'Date': '2017-06-10', 'Precipitation': 13.5},
#  {'Date': '2017-06-10', 'Precipitation': 3.3},
#  {'Date': '2017-06-10', 'Precipitation': 15.7},
#  {'Date': '2017-06-10', 'Precipitation': None},
#  {'Date': '2017-06-09', 'Precipitation': 0.0},
#  {'Date': '2017-06-09', 'Precipitation': 0.5},
#  {'Date': '2017-06-09', 'Precipitation': 0.0},
#  {'Date': '2017-06-09', 'Precipitation': None},
#  {'Date': '2017-06-09', 'Precipitation': 0.0},
#  {'Date': '2017-06-09', 'Precipitation': 0.5},
#  {'Date': '2017-06-08', 'Precipitation': 0.0},
#  {'Date': '2017-06-08', 'Precipitation': 0.5},
#  {'Date': '2017-06-08', 'Precipitation': 0.3},
#  {'Date': '2017-06-08', 'Precipitation': None},
#  {'Date': '2017-06-08', 'Precipitation': 0.0},
#  {'Date': '2017-06-08', 'Precipitation': 0.0},
#  {'Date': '2017-06-08', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': None},
#  {'Date': '2017-06-07', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': 0.0},
#  {'Date': '2017-06-07', 'Precipitation': 0.3},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-06', 'Precipitation': None},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-06', 'Precipitation': 0.0},
#  {'Date': '2017-06-05', 'Precipitation': 0.0},
#  {'Date': '2017-06-05', 'Precipitation': 0.0},
#  {'Date': '2017-06-05', 'Precipitation': 0.5},
#  {'Date': '2017-06-05', 'Precipitation': None},
#  {'Date': '2017-06-05', 'Precipitation': 0.0},
#  {'Date': '2017-06-05', 'Precipitation': 1.3},
#  {'Date': '2017-06-05', 'Precipitation': 0.3},
#  {'Date': '2017-06-04', 'Precipitation': 0.0},
#  {'Date': '2017-06-04', 'Precipitation': 3.8},
#  {'Date': '2017-06-04', 'Precipitation': 1.3},
#  {'Date': '2017-06-04', 'Precipitation': 0.0},
#  {'Date': '2017-06-04', 'Precipitation': 3.3},
#  {'Date': '2017-06-04', 'Precipitation': 20.8},
#  {'Date': '2017-06-03', 'Precipitation': 0.5},
#  {'Date': '2017-06-03', 'Precipitation': 5.1},
#  {'Date': '2017-06-03', 'Precipitation': 4.1},
#  {'Date': '2017-06-03', 'Precipitation': 3.8},
#  {'Date': '2017-06-03', 'Precipitation': 2.0},
#  {'Date': '2017-06-03', 'Precipitation': None},
#  {'Date': '2017-06-02', 'Precipitation': 0.0},
#  {'Date': '2017-06-02', 'Precipitation': 2.5},
#  {'Date': '2017-06-02', 'Precipitation': 3.8},
#  {'Date': '2017-06-02', 'Precipitation': None},
#  {'Date': '2017-06-02', 'Precipitation': 0.0},
#  {'Date': '2017-06-02', 'Precipitation': 2.3},
#  {'Date': '2017-06-01', 'Precipitation': 0.0},
#  {'Date': '2017-06-01', 'Precipitation': 0.8},
#  {'Date': '2017-06-01', 'Precipitation': 0.0},
#  {'Date': '2017-06-01', 'Precipitation': 0.0},
#  {'Date': '2017-06-01', 'Precipitation': 0.0},
#  {'Date': '2017-06-01', 'Precipitation': 0.3},
#  {'Date': '2017-05-31', 'Precipitation': 0.5},
#  {'Date': '2017-05-31', 'Precipitation': 2.5},
#  {'Date': '2017-05-31', 'Precipitation': 0.0},
#  {'Date': '2017-05-31', 'Precipitation': 0.0},
#  {'Date': '2017-05-31', 'Precipitation': 6.4},
#  {'Date': '2017-05-30', 'Precipitation': 6.6},
#  {'Date': '2017-05-30', 'Precipitation': 5.1},
#  {'Date': '2017-05-30', 'Precipitation': 1.0},
#  {'Date': '2017-05-30', 'Precipitation': 2.8},
#  {'Date': '2017-05-30', 'Precipitation': 28.4},
#  {'Date': '2017-05-30', 'Precipitation': None},
#  {'Date': '2017-05-29', 'Precipitation': 0.0},
#  {'Date': '2017-05-29', 'Precipitation': 0.5},
#  {'Date': '2017-05-29', 'Precipitation': 0.0},
#  {'Date': '2017-05-29', 'Precipitation': 0.0},
#  {'Date': '2017-05-29', 'Precipitation': 10.2},
#  {'Date': '2017-05-28', 'Precipitation': 0.5},
#  {'Date': '2017-05-28', 'Precipitation': 7.4},
#  {'Date': '2017-05-28', 'Precipitation': 0.5},
#  {'Date': '2017-05-28', 'Precipitation': 0.0},
#  {'Date': '2017-05-28', 'Precipitation': 2.0},
#  {'Date': '2017-05-28', 'Precipitation': 0.0},
#  {'Date': '2017-05-27', 'Precipitation': 0.3},
#  {'Date': '2017-05-27', 'Precipitation': 0.0},
#  {'Date': '2017-05-27', 'Precipitation': 0.0},
#  {'Date': '2017-05-27', 'Precipitation': 0.0},
#  {'Date': '2017-05-27', 'Precipitation': 0.0},
#  {'Date': '2017-05-27', 'Precipitation': 12.7},
#  {'Date': '2017-05-26', 'Precipitation': 0.5},
#  {'Date': '2017-05-26', 'Precipitation': 0.0},
#  {'Date': '2017-05-26', 'Precipitation': 0.0},
#  {'Date': '2017-05-26', 'Precipitation': 0.0},
#  {'Date': '2017-05-26', 'Precipitation': 0.0},
#  {'Date': '2017-05-25', 'Precipitation': 3.8},
#  {'Date': '2017-05-25', 'Precipitation': 9.4},
#  {'Date': '2017-05-25', 'Precipitation': 1.8},
#  {'Date': '2017-05-25', 'Precipitation': 14.0},
#  {'Date': '2017-05-25', 'Precipitation': 5.1},
#  {'Date': '2017-05-25', 'Precipitation': 22.4},
#  {'Date': '2017-05-24', 'Precipitation': 3.3},
#  {'Date': '2017-05-24', 'Precipitation': 14.7},
#  {'Date': '2017-05-24', 'Precipitation': 2.5},
#  {'Date': '2017-05-24', 'Precipitation': 15.5},
#  {'Date': '2017-05-24', 'Precipitation': 7.6},
#  {'Date': '2017-05-24', 'Precipitation': 55.1},
#  {'Date': '2017-05-23', 'Precipitation': 2.0},
#  {'Date': '2017-05-23', 'Precipitation': 0.5},
#  {'Date': '2017-05-23', 'Precipitation': 2.8},
#  {'Date': '2017-05-23', 'Precipitation': 0.0},
#  {'Date': '2017-05-23', 'Precipitation': 1.5},
#  {'Date': '2017-05-23', 'Precipitation': 11.2},
#  {'Date': '2017-05-22', 'Precipitation': 0.0},
#  {'Date': '2017-05-22', 'Precipitation': 0.0},
#  {'Date': '2017-05-22', 'Precipitation': None},
#  {'Date': '2017-05-22', 'Precipitation': 0.0},
#  {'Date': '2017-05-22', 'Precipitation': 1.5},
#  {'Date': '2017-05-22', 'Precipitation': 7.6},
#  {'Date': '2017-05-21', 'Precipitation': 0.0},
#  {'Date': '2017-05-21', 'Precipitation': 0.0},
#  {'Date': '2017-05-21', 'Precipitation': 0.0},
#  {'Date': '2017-05-21', 'Precipitation': 0.3},
#  {'Date': '2017-05-21', 'Precipitation': 0.0},
#  {'Date': '2017-05-20', 'Precipitation': 0.0},
#  {'Date': '2017-05-20', 'Precipitation': 0.0},
#  {'Date': '2017-05-20', 'Precipitation': 0.3},
#  {'Date': '2017-05-20', 'Precipitation': None},
#  {'Date': '2017-05-20', 'Precipitation': 0.5},
#  {'Date': '2017-05-20', 'Precipitation': None},
#  {'Date': '2017-05-19', 'Precipitation': 0.0},
#  {'Date': '2017-05-19', 'Precipitation': 0.5},
#  {'Date': '2017-05-19', 'Precipitation': 0.3},
#  {'Date': '2017-05-19', 'Precipitation': 0.3},
#  {'Date': '2017-05-18', 'Precipitation': 0.3},
#  {'Date': '2017-05-18', 'Precipitation': 2.3},
#  {'Date': '2017-05-18', 'Precipitation': 4.1},
#  {'Date': '2017-05-18', 'Precipitation': 11.7},
#  {'Date': '2017-05-18', 'Precipitation': 3.3},
#  {'Date': '2017-05-18', 'Precipitation': 0.0},
#  {'Date': '2017-05-17', 'Precipitation': 0.0},
#  {'Date': '2017-05-17', 'Precipitation': 0.5},
#  {'Date': '2017-05-17', 'Precipitation': 0.0},
#  {'Date': '2017-05-17', 'Precipitation': 0.0},
#  {'Date': '2017-05-17', 'Precipitation': 1.8},
#  {'Date': '2017-05-17', 'Precipitation': 1.5},
#  {'Date': '2017-05-16', 'Precipitation': 0.3},
#  {'Date': '2017-05-16', 'Precipitation': 0.8},
#  {'Date': '2017-05-16', 'Precipitation': 1.3},
#  {'Date': '2017-05-16', 'Precipitation': 0.0},
#  {'Date': '2017-05-16', 'Precipitation': 0.8},
#  {'Date': '2017-05-16', 'Precipitation': 7.6},
#  {'Date': '2017-05-15', 'Precipitation': 1.3},
#  {'Date': '2017-05-15', 'Precipitation': 2.0},
#  {'Date': '2017-05-15', 'Precipitation': None},
#  {'Date': '2017-05-15', 'Precipitation': 1.5},
#  {'Date': '2017-05-15', 'Precipitation': 2.3},
#  {'Date': '2017-05-15', 'Precipitation': 15.2},
#  {'Date': '2017-05-14', 'Precipitation': 0.0},
#  {'Date': '2017-05-14', 'Precipitation': 1.3},
#  {'Date': '2017-05-14', 'Precipitation': 0.0},
#  {'Date': '2017-05-14', 'Precipitation': 4.3},
#  {'Date': '2017-05-14', 'Precipitation': 25.4},
#  {'Date': '2017-05-13', 'Precipitation': 0.0},
#  {'Date': '2017-05-13', 'Precipitation': 0.5},
#  {'Date': '2017-05-13', 'Precipitation': 0.0},
#  {'Date': '2017-05-13', 'Precipitation': 3.0},
#  {'Date': '2017-05-13', 'Precipitation': 2.5},
#  {'Date': '2017-05-12', 'Precipitation': 0.0},
#  {'Date': '2017-05-12', 'Precipitation': 1.0},
#  {'Date': '2017-05-12', 'Precipitation': None},
#  {'Date': '2017-05-12', 'Precipitation': 0.0},
#  {'Date': '2017-05-12', 'Precipitation': 0.5},
#  {'Date': '2017-05-12', 'Precipitation': 2.5},
#  {'Date': '2017-05-11', 'Precipitation': 0.3},
#  {'Date': '2017-05-11', 'Precipitation': 0.8},
#  {'Date': '2017-05-11', 'Precipitation': 0.0},
#  {'Date': '2017-05-11', 'Precipitation': 3.0},
#  {'Date': '2017-05-11', 'Precipitation': 11.2},
#  {'Date': '2017-05-10', 'Precipitation': 0.0},
#  {'Date': '2017-05-10', 'Precipitation': 1.3},
#  {'Date': '2017-05-10', 'Precipitation': 0.0},
#  {'Date': '2017-05-10', 'Precipitation': 1.5},
#  {'Date': '2017-05-10', 'Precipitation': 5.1},
#  {'Date': '2017-05-10', 'Precipitation': 14.0},
#  {'Date': '2017-05-09', 'Precipitation': 41.1},
#  {'Date': '2017-05-09', 'Precipitation': 13.2},
#  {'Date': '2017-05-09', 'Precipitation': 17.3},
#  {'Date': '2017-05-09', 'Precipitation': 40.1},
#  {'Date': '2017-05-09', 'Precipitation': 5.8},
#  {'Date': '2017-05-08', 'Precipitation': 0.0},
#  {'Date': '2017-05-08', 'Precipitation': 5.6},
#  {'Date': '2017-05-08', 'Precipitation': 24.1},
#  {'Date': '2017-05-08', 'Precipitation': 0.0},
#  {'Date': '2017-05-08', 'Precipitation': 18.5},
#  {'Date': '2017-05-08', 'Precipitation': 28.2},
#  {'Date': '2017-05-07', 'Precipitation': 0.0},
#  {'Date': '2017-05-07', 'Precipitation': 1.8},
#  {'Date': '2017-05-07', 'Precipitation': 0.0},
#  {'Date': '2017-05-07', 'Precipitation': 0.5},
#  {'Date': '2017-05-07', 'Precipitation': 0.8},
#  {'Date': '2017-05-06', 'Precipitation': 0.0},
#  {'Date': '2017-05-06', 'Precipitation': 0.0},
#  {'Date': '2017-05-06', 'Precipitation': 1.5},
#  {'Date': '2017-05-06', 'Precipitation': 0.0},
#  {'Date': '2017-05-06', 'Precipitation': 0.0},
#  {'Date': '2017-05-06', 'Precipitation': 0.0},
#  {'Date': '2017-05-05', 'Precipitation': 0.0},
#  {'Date': '2017-05-05', 'Precipitation': 0.0},
#  {'Date': '2017-05-05', 'Precipitation': 7.1},
#  {'Date': '2017-05-05', 'Precipitation': 0.0},
#  {'Date': '2017-05-05', 'Precipitation': 0.0},
#  {'Date': '2017-05-05', 'Precipitation': 2.5},
#  {'Date': '2017-05-04', 'Precipitation': 0.0},
#  {'Date': '2017-05-04', 'Precipitation': 0.0},
#  {'Date': '2017-05-04', 'Precipitation': 2.0},
#  {'Date': '2017-05-04', 'Precipitation': 0.0},
#  {'Date': '2017-05-04', 'Precipitation': 0.0},
#  {'Date': '2017-05-04', 'Precipitation': None},
#  {'Date': '2017-05-03', 'Precipitation': 0.0},
#  {'Date': '2017-05-03', 'Precipitation': 0.3},
#  {'Date': '2017-05-03', 'Precipitation': 0.3},
#  {'Date': '2017-05-03', 'Precipitation': 0.0},
#  {'Date': '2017-05-03', 'Precipitation': 0.3},
#  {'Date': '2017-05-02', 'Precipitation': 0.0},
#  {'Date': '2017-05-02', 'Precipitation': 0.8},
#  {'Date': '2017-05-02', 'Precipitation': 0.3},
#  {'Date': '2017-05-02', 'Precipitation': 0.0},
#  {'Date': '2017-05-02', 'Precipitation': 0.3},
#  {'Date': '2017-05-02', 'Precipitation': 0.0},
#  {'Date': '2017-05-01', 'Precipitation': 6.6},
#  {'Date': '2017-05-01', 'Precipitation': 1.8},
#  {'Date': '2017-05-01', 'Precipitation': 0.8},
#  {'Date': '2017-05-01', 'Precipitation': 1.8},
#  {'Date': '2017-05-01', 'Precipitation': 3.3},
#  {'Date': '2017-05-01', 'Precipitation': 6.4},
#  {'Date': '2017-04-30', 'Precipitation': 22.6},
#  {'Date': '2017-04-30', 'Precipitation': 30.7},
#  {'Date': '2017-04-30', 'Precipitation': 29.7},
#  {'Date': '2017-04-30', 'Precipitation': 33.3},
#  {'Date': '2017-04-30', 'Precipitation': 26.4},
#  {'Date': '2017-04-30', 'Precipitation': 20.3},
#  {'Date': '2017-04-29', 'Precipitation': 3.0},
#  {'Date': '2017-04-29', 'Precipitation': 8.9},
#  {'Date': '2017-04-29', 'Precipitation': 24.1},
#  {'Date': '2017-04-29', 'Precipitation': 158.8},
#  {'Date': '2017-04-29', 'Precipitation': 9.4},
#  {'Date': '2017-04-29', 'Precipitation': 0.0},
#  {'Date': '2017-04-28', 'Precipitation': 0.0},
#  {'Date': '2017-04-28', 'Precipitation': 66.0},
#  {'Date': '2017-04-28', 'Precipitation': 2.3},
#  {'Date': '2017-04-28', 'Precipitation': None},
#  {'Date': '2017-04-28', 'Precipitation': 0.0},
#  {'Date': '2017-04-28', 'Precipitation': 19.3},
#  {'Date': '2017-04-28', 'Precipitation': 20.1},
#  {'Date': '2017-04-27', 'Precipitation': 0.0},
#  {'Date': '2017-04-27', 'Precipitation': 2.5},
#  {'Date': '2017-04-27', 'Precipitation': 0.5},
#  {'Date': '2017-04-27', 'Precipitation': None},
#  {'Date': '2017-04-27', 'Precipitation': 0.0},
#  {'Date': '2017-04-27', 'Precipitation': 4.8},
#  {'Date': '2017-04-27', 'Precipitation': 2.8},
#  {'Date': '2017-04-26', 'Precipitation': 0.0},
#  {'Date': '2017-04-26', 'Precipitation': 0.0},
#  {'Date': '2017-04-26', 'Precipitation': 3.6},
#  {'Date': '2017-04-26', 'Precipitation': 0.3},
#  {'Date': '2017-04-26', 'Precipitation': 0.5},
#  {'Date': '2017-04-26', 'Precipitation': 5.6},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-25', 'Precipitation': None},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-25', 'Precipitation': 0.0},
#  {'Date': '2017-04-24', 'Precipitation': 0.0},
#  {'Date': '2017-04-24', 'Precipitation': 0.0},
#  {'Date': '2017-04-24', 'Precipitation': None},
#  {'Date': '2017-04-24', 'Precipitation': None},
#  {'Date': '2017-04-24', 'Precipitation': None},
#  {'Date': '2017-04-24', 'Precipitation': 0.3},
#  {'Date': '2017-04-24', 'Precipitation': 1.3},
#  {'Date': '2017-04-23', 'Precipitation': 0.8},
#  {'Date': '2017-04-23', 'Precipitation': 0.5},
#  {'Date': '2017-04-23', 'Precipitation': 1.5},
#  {'Date': '2017-04-23', 'Precipitation': 8.9},
#  {'Date': '2017-04-22', 'Precipitation': 8.1},
#  {'Date': '2017-04-22', 'Precipitation': 25.7},
#  {'Date': '2017-04-22', 'Precipitation': 17.8},
#  {'Date': '2017-04-22', 'Precipitation': 40.1},
#  {'Date': '2017-04-22', 'Precipitation': 34.3},
#  {'Date': '2017-04-21', 'Precipitation': 5.8},
#  {'Date': '2017-04-21', 'Precipitation': 29.5},
#  {'Date': '2017-04-21', 'Precipitation': 26.7},
#  {'Date': '2017-04-21', 'Precipitation': None},
#  {'Date': '2017-04-21', 'Precipitation': 59.9},
#  {'Date': '2017-04-21', 'Precipitation': 44.2},
#  {'Date': '2017-04-21', 'Precipitation': 46.7},
#  {'Date': '2017-04-20', 'Precipitation': 1.3},
#  {'Date': '2017-04-20', 'Precipitation': 8.4},
#  {'Date': '2017-04-20', 'Precipitation': 0.0},
#  {'Date': '2017-04-20', 'Precipitation': None},
#  {'Date': '2017-04-20', 'Precipitation': 8.9},
#  {'Date': '2017-04-20', 'Precipitation': 1.3},
#  {'Date': '2017-04-20', 'Precipitation': 0.0},
#  {'Date': '2017-04-19', 'Precipitation': 0.5},
#  {'Date': '2017-04-19', 'Precipitation': 0.5},
#  {'Date': '2017-04-19', 'Precipitation': 0.0},
#  {'Date': '2017-04-19', 'Precipitation': None},
#  {'Date': '2017-04-19', 'Precipitation': 0.0},
#  {'Date': '2017-04-19', 'Precipitation': 0.5},
#  {'Date': '2017-04-19', 'Precipitation': 3.6},
#  {'Date': '2017-04-18', 'Precipitation': 0.0},
#  {'Date': '2017-04-18', 'Precipitation': 2.0},
#  {'Date': '2017-04-18', 'Precipitation': 3.0},
#  {'Date': '2017-04-18', 'Precipitation': 0.0},
#  {'Date': '2017-04-18', 'Precipitation': 3.8},
#  {'Date': '2017-04-18', 'Precipitation': 51.6},
#  {'Date': '2017-04-18', 'Precipitation': 24.9},
#  {'Date': '2017-04-17', 'Precipitation': 0.5},
#  {'Date': '2017-04-17', 'Precipitation': 10.4},
#  {'Date': '2017-04-17', 'Precipitation': None},
#  {'Date': '2017-04-17', 'Precipitation': None},
#  {'Date': '2017-04-17', 'Precipitation': 7.6},
#  {'Date': '2017-04-17', 'Precipitation': 26.4},
#  {'Date': '2017-04-17', 'Precipitation': 33.0},
#  {'Date': '2017-04-16', 'Precipitation': 0.0},
#  {'Date': '2017-04-16', 'Precipitation': 12.4},
#  {'Date': '2017-04-16', 'Precipitation': 0.0},
#  {'Date': '2017-04-16', 'Precipitation': 11.9},
#  {'Date': '2017-04-16', 'Precipitation': 2.8},
#  {'Date': '2017-04-15', 'Precipitation': 0.3},
#  {'Date': '2017-04-15', 'Precipitation': 11.4},
#  {'Date': '2017-04-15', 'Precipitation': 0.0},
#  {'Date': '2017-04-15', 'Precipitation': 9.7},
#  {'Date': '2017-04-15', 'Precipitation': 22.9},
#  {'Date': '2017-04-14', 'Precipitation': 6.6},
#  {'Date': '2017-04-14', 'Precipitation': 17.5},
#  {'Date': '2017-04-14', 'Precipitation': 7.4},
#  {'Date': '2017-04-14', 'Precipitation': 9.1},
#  {'Date': '2017-04-14', 'Precipitation': 58.4},
#  {'Date': '2017-04-14', 'Precipitation': 71.6},
#  {'Date': '2017-04-13', 'Precipitation': 0.0},
#  {'Date': '2017-04-13', 'Precipitation': 6.9},
#  {'Date': '2017-04-13', 'Precipitation': 0.0},
#  {'Date': '2017-04-13', 'Precipitation': None},
#  {'Date': '2017-04-13', 'Precipitation': 0.0},
#  {'Date': '2017-04-13', 'Precipitation': 15.0},
#  {'Date': '2017-04-13', 'Precipitation': 5.8},
#  {'Date': '2017-04-12', 'Precipitation': 0.0},
#  {'Date': '2017-04-12', 'Precipitation': 0.8},
#  {'Date': '2017-04-12', 'Precipitation': 7.4},
#  {'Date': '2017-04-12', 'Precipitation': None},
#  {'Date': '2017-04-12', 'Precipitation': 0.0},
#  {'Date': '2017-04-12', 'Precipitation': 2.8},
#  {'Date': '2017-04-12', 'Precipitation': 16.5},
#  {'Date': '2017-04-11', 'Precipitation': 0.0},
#  {'Date': '2017-04-11', 'Precipitation': 0.8},
#  {'Date': '2017-04-11', 'Precipitation': 4.1},
#  {'Date': '2017-04-11', 'Precipitation': None},
#  {'Date': '2017-04-11', 'Precipitation': 0.0},
#  {'Date': '2017-04-11', 'Precipitation': 0.8},
#  {'Date': '2017-04-11', 'Precipitation': 6.4},
#  {'Date': '2017-04-10', 'Precipitation': 0.0},
#  {'Date': '2017-04-10', 'Precipitation': 0.3},
#  {'Date': '2017-04-10', 'Precipitation': 0.0},
#  {'Date': '2017-04-10', 'Precipitation': None},
#  {'Date': '2017-04-10', 'Precipitation': 0.0},
#  {'Date': '2017-04-10', 'Precipitation': 0.3},
#  {'Date': '2017-04-10', 'Precipitation': 0.0},
#  {'Date': '2017-04-09', 'Precipitation': 0.0},
#  {'Date': '2017-04-09', 'Precipitation': 0.0},
#  {'Date': '2017-04-09', 'Precipitation': None},
#  {'Date': '2017-04-09', 'Precipitation': None},
#  {'Date': '2017-04-09', 'Precipitation': 0.0},
#  {'Date': '2017-04-09', 'Precipitation': 0.0},
#  {'Date': '2017-04-08', 'Precipitation': 0.0},
#  {'Date': '2017-04-08', 'Precipitation': 0.0},
#  {'Date': '2017-04-08', 'Precipitation': 0.0},
#  {'Date': '2017-04-08', 'Precipitation': None},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-07', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-06', 'Precipitation': 1.5},
#  {'Date': '2017-04-06', 'Precipitation': 0.0},
#  {'Date': '2017-04-05', 'Precipitation': 0.0},
#  {'Date': '2017-04-05', 'Precipitation': 1.0},
#  {'Date': '2017-04-05', 'Precipitation': 1.8},
#  {'Date': '2017-04-05', 'Precipitation': 0.0},
#  {'Date': '2017-04-05', 'Precipitation': 0.0},
#  {'Date': '2017-04-05', 'Precipitation': 2.5},
#  {'Date': '2017-04-05', 'Precipitation': 11.4},
#  {'Date': '2017-04-04', 'Precipitation': 0.0},
#  {'Date': '2017-04-04', 'Precipitation': 1.0},
#  {'Date': '2017-04-04', 'Precipitation': 0.0},
#  {'Date': '2017-04-04', 'Precipitation': 0.0},
#  {'Date': '2017-04-04', 'Precipitation': 0.0},
#  {'Date': '2017-04-04', 'Precipitation': 2.3},
#  {'Date': '2017-04-04', 'Precipitation': 0.5},
#  {'Date': '2017-04-03', 'Precipitation': 0.0},
#  {'Date': '2017-04-03', 'Precipitation': 2.0},
#  {'Date': '2017-04-03', 'Precipitation': 2.3},
#  {'Date': '2017-04-03', 'Precipitation': None},
#  {'Date': '2017-04-03', 'Precipitation': 0.0},
#  {'Date': '2017-04-03', 'Precipitation': 6.6},
#  {'Date': '2017-04-03', 'Precipitation': 5.8},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-02', 'Precipitation': 0.0},
#  {'Date': '2017-04-01', 'Precipitation': 0.0},
#  {'Date': '2017-04-01', 'Precipitation': 0.0},
#  {'Date': '2017-04-01', 'Precipitation': 0.0},
#  {'Date': '2017-04-01', 'Precipitation': 0.0},
#  {'Date': '2017-04-01', 'Precipitation': 5.3},
#  {'Date': '2017-04-01', 'Precipitation': 5.1},
#  {'Date': '2017-03-31', 'Precipitation': 0.0},
#  {'Date': '2017-03-31', 'Precipitation': 0.0},
#  {'Date': '2017-03-31', 'Precipitation': 0.0},
#  {'Date': '2017-03-31', 'Precipitation': 0.0},
#  {'Date': '2017-03-31', 'Precipitation': 0.0},
#  {'Date': '2017-03-31', 'Precipitation': 0.3},
#  {'Date': '2017-03-31', 'Precipitation': None},
#  {'Date': '2017-03-30', 'Precipitation': 0.0},
#  {'Date': '2017-03-30', 'Precipitation': 2.0},
#  {'Date': '2017-03-30', 'Precipitation': 0.8},
#  {'Date': '2017-03-30', 'Precipitation': None},
#  {'Date': '2017-03-30', 'Precipitation': 0.0},
#  {'Date': '2017-03-30', 'Precipitation': 1.0},
#  {'Date': '2017-03-29', 'Precipitation': 0.0},
#  {'Date': '2017-03-29', 'Precipitation': 0.0},
#  {'Date': '2017-03-29', 'Precipitation': 0.8},
#  {'Date': '2017-03-29', 'Precipitation': None},
#  {'Date': '2017-03-29', 'Precipitation': 2.0},
#  {'Date': '2017-03-29', 'Precipitation': 0.3},
#  {'Date': '2017-03-29', 'Precipitation': 1.8},
#  {'Date': '2017-03-28', 'Precipitation': 0.0},
#  {'Date': '2017-03-28', 'Precipitation': 0.8},
#  {'Date': '2017-03-28', 'Precipitation': 0.0},
#  {'Date': '2017-03-28', 'Precipitation': None},
#  {'Date': '2017-03-28', 'Precipitation': 0.0},
#  {'Date': '2017-03-28', 'Precipitation': 0.0},
#  {'Date': '2017-03-28', 'Precipitation': 17.3},
#  {'Date': '2017-03-27', 'Precipitation': 0.0},
#  {'Date': '2017-03-27', 'Precipitation': 0.0},
#  {'Date': '2017-03-27', 'Precipitation': None},
#  {'Date': '2017-03-27', 'Precipitation': 0.0},
#  {'Date': '2017-03-27', 'Precipitation': 0.3},
#  {'Date': '2017-03-27', 'Precipitation': 0.0},
#  {'Date': '2017-03-26', 'Precipitation': 0.0},
#  {'Date': '2017-03-26', 'Precipitation': 0.0},
#  {'Date': '2017-03-26', 'Precipitation': 0.0},
#  {'Date': '2017-03-26', 'Precipitation': 0.0},
#  {'Date': '2017-03-26', 'Precipitation': 0.0},
#  {'Date': '2017-03-25', 'Precipitation': 0.0},
#  {'Date': '2017-03-25', 'Precipitation': 3.3},
#  {'Date': '2017-03-25', 'Precipitation': 10.9},
#  {'Date': '2017-03-25', 'Precipitation': 23.6},
#  {'Date': '2017-03-25', 'Precipitation': 12.2},
#  {'Date': '2017-03-24', 'Precipitation': 0.5},
#  {'Date': '2017-03-24', 'Precipitation': 15.2},
#  {'Date': '2017-03-24', 'Precipitation': 3.8},
#  {'Date': '2017-03-24', 'Precipitation': 1.8},
#  {'Date': '2017-03-24', 'Precipitation': 3.0},
#  {'Date': '2017-03-24', 'Precipitation': 4.3},
#  {'Date': '2017-03-23', 'Precipitation': 0.0},
#  {'Date': '2017-03-23', 'Precipitation': 0.0},
#  {'Date': '2017-03-23', 'Precipitation': 0.0},
#  {'Date': '2017-03-23', 'Precipitation': 0.5},
#  {'Date': '2017-03-23', 'Precipitation': 0.0},
#  {'Date': '2017-03-23', 'Precipitation': 0.8},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-22', 'Precipitation': 0.0},
#  {'Date': '2017-03-21', 'Precipitation': 0.0},
#  {'Date': '2017-03-21', 'Precipitation': 0.0},
#  {'Date': '2017-03-21', 'Precipitation': 0.0},
#  {'Date': '2017-03-21', 'Precipitation': 0.0},
#  {'Date': '2017-03-21', 'Precipitation': 2.3},
#  {'Date': '2017-03-21', 'Precipitation': 0.0},
#  {'Date': '2017-03-20', 'Precipitation': 0.0},
#  {'Date': '2017-03-20', 'Precipitation': 0.0},
#  {'Date': '2017-03-20', 'Precipitation': None},
#  {'Date': '2017-03-20', 'Precipitation': 0.0},
#  {'Date': '2017-03-20', 'Precipitation': 0.5},
#  {'Date': '2017-03-20', 'Precipitation': 0.0},
#  {'Date': '2017-03-19', 'Precipitation': 0.0},
#  {'Date': '2017-03-19', 'Precipitation': 0.0},
#  {'Date': '2017-03-19', 'Precipitation': 0.0},
#  {'Date': '2017-03-19', 'Precipitation': 0.0},
#  {'Date': '2017-03-19', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': 0.0},
#  {'Date': '2017-03-18', 'Precipitation': None},
#  {'Date': '2017-03-17', 'Precipitation': 0.0},
#  {'Date': '2017-03-17', 'Precipitation': 4.8},
#  {'Date': '2017-03-17', 'Precipitation': 1.5},
#  {'Date': '2017-03-17', 'Precipitation': None},
#  {'Date': '2017-03-17', 'Precipitation': 8.9},
#  {'Date': '2017-03-17', 'Precipitation': 3.0},
#  {'Date': '2017-03-16', 'Precipitation': 0.0},
#  {'Date': '2017-03-16', 'Precipitation': 0.0},
#  {'Date': '2017-03-16', 'Precipitation': None},
#  {'Date': '2017-03-16', 'Precipitation': None},
#  {'Date': '2017-03-16', 'Precipitation': 0.0},
#  {'Date': '2017-03-16', 'Precipitation': 0.0},
#  {'Date': '2017-03-16', 'Precipitation': 0.0},
#  {'Date': '2017-03-15', 'Precipitation': 0.0},
#  {'Date': '2017-03-15', 'Precipitation': 0.0},
#  {'Date': '2017-03-15', 'Precipitation': 0.0},
#  {'Date': '2017-03-15', 'Precipitation': 0.0},
#  {'Date': '2017-03-15', 'Precipitation': 1.5},
#  {'Date': '2017-03-15', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 1.5},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-14', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': None},
#  {'Date': '2017-03-13', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': 0.0},
#  {'Date': '2017-03-13', 'Precipitation': None},
#  {'Date': '2017-03-12', 'Precipitation': 0.0},
#  {'Date': '2017-03-12', 'Precipitation': 0.0},
#  {'Date': '2017-03-12', 'Precipitation': None},
#  {'Date': '2017-03-12', 'Precipitation': 0.0},
#  {'Date': '2017-03-12', 'Precipitation': 0.0},
#  {'Date': '2017-03-11', 'Precipitation': 0.0},
#  {'Date': '2017-03-11', 'Precipitation': 0.8},
#  {'Date': '2017-03-11', 'Precipitation': 0.0},
#  {'Date': '2017-03-11', 'Precipitation': 0.3},
#  {'Date': '2017-03-11', 'Precipitation': 0.0},
#  {'Date': '2017-03-10', 'Precipitation': 0.0},
#  {'Date': '2017-03-10', 'Precipitation': 3.3},
#  {'Date': '2017-03-10', 'Precipitation': 3.3},
#  {'Date': '2017-03-10', 'Precipitation': 0.0},
#  {'Date': '2017-03-10', 'Precipitation': 0.0},
#  {'Date': '2017-03-10', 'Precipitation': 0.8},
#  {'Date': '2017-03-10', 'Precipitation': 0.0},
#  {'Date': '2017-03-09', 'Precipitation': 0.0},
#  {'Date': '2017-03-09', 'Precipitation': 20.3},
#  {'Date': '2017-03-09', 'Precipitation': 12.7},
#  {'Date': '2017-03-09', 'Precipitation': 0.0},
#  {'Date': '2017-03-09', 'Precipitation': None},
#  {'Date': '2017-03-09', 'Precipitation': 16.5},
#  {'Date': '2017-03-09', 'Precipitation': 0.3},
#  {'Date': '2017-03-08', 'Precipitation': 0.0},
#  {'Date': '2017-03-08', 'Precipitation': 0.0},
#  {'Date': '2017-03-08', 'Precipitation': 0.0},
#  {'Date': '2017-03-08', 'Precipitation': None},
#  {'Date': '2017-03-08', 'Precipitation': 0.0},
#  {'Date': '2017-03-08', 'Precipitation': 0.0},
#  {'Date': '2017-03-07', 'Precipitation': 0.0},
#  {'Date': '2017-03-07', 'Precipitation': 0.0},
#  {'Date': '2017-03-07', 'Precipitation': 0.0},
#  {'Date': '2017-03-07', 'Precipitation': None},
#  {'Date': '2017-03-07', 'Precipitation': 0.0},
#  {'Date': '2017-03-07', 'Precipitation': 0.0},
#  {'Date': '2017-03-06', 'Precipitation': 0.0},
#  {'Date': '2017-03-06', 'Precipitation': 13.0},
#  {'Date': '2017-03-06', 'Precipitation': None},
#  {'Date': '2017-03-06', 'Precipitation': None},
#  {'Date': '2017-03-06', 'Precipitation': None},
#  {'Date': '2017-03-06', 'Precipitation': 0.8},
#  {'Date': '2017-03-06', 'Precipitation': 0.0},
#  ...]

# %%
# Calculate the date one year from the last date in data set.
# Perform a query to retrieve the data and precipitation scores
# Save the query results as a Pandas DataFrame and set the index to the date column
prior12_df = pd.DataFrame(prior12_rows)
prior12_df

# # Sort the dataframe by date
df = prior12_df.set_index('Date', drop=False)
df = df.sort_index()

# %%
# Use Pandas Plotting with Matplotlib to plot the data
df.plot(x='Date', y='Precipitation', rot=90)
plt.xlabel("Date")
plt.ylabel("mm")
# Out:
# Text(0, 0.5, 'mm')

# %%
df["Precipitation"].describe()
# Out:
# count    2015.000000
# mean        4.485112
# std        11.690532
# min         0.000000
# 25%         0.000000
# 50%         0.500000
# 75%         3.300000
# max       170.200000
# Name: Precipitation, dtype: float64

# %%
prior12_df[['Date', 'Precipitation']].groupby('Date').mean()
# Out:
#             Precipitation
# Date
# 2016-08-24      39.483333
# 2016-08-25       1.942857
# 2016-08-26       0.433333
# 2016-08-27       1.620000
# 2016-08-28      13.150000
# ...                   ...
# 2017-08-19       0.766667
# 2017-08-20       0.150000
# 2017-08-21       4.900000
# 2017-08-22       4.233333
# 2017-08-23       3.350000
#
# [365 rows x 1 columns]

# %%
prior12_df[['Date', 'Precipitation']].groupby('Date').describe()
# Out:
#            Precipitation                                                    \
#                    count       mean        std  min     25%    50%     75%
# Date
# 2016-08-24           6.0  39.483333  21.355881  2.0  32.450  45.70  54.600
# 2016-08-25           7.0   1.942857   1.814623  0.0   0.750   2.00   2.400
# 2016-08-26           6.0   0.433333   0.413118  0.0   0.075   0.40   0.725
# 2016-08-27           5.0   1.620000   2.078942  0.0   0.000   0.50   3.000
# 2016-08-28           6.0  13.150000  19.996175  0.3   3.600   3.60  12.300
# ...                  ...        ...        ...  ...     ...    ...     ...
# 2017-08-19           3.0   0.766667   1.327906  0.0   0.000   0.00   1.150
# 2017-08-20           2.0   0.150000   0.212132  0.0   0.075   0.15   0.225
# 2017-08-21           3.0   4.900000   8.057915  0.0   0.250   0.50   7.350
# 2017-08-22           3.0   4.233333   7.332348  0.0   0.000   0.00   6.350
# 2017-08-23           4.0   3.350000   5.448853  0.0   0.000   1.00   4.350
#
#
#              max
# Date
# 2016-08-24  57.9
# 2016-08-25   5.3
# 2016-08-26   1.0
# 2016-08-27   4.6
# 2016-08-28  52.6
# ...          ...
# 2017-08-19   2.3
# 2017-08-20   0.3
# 2017-08-21  14.2
# 2017-08-22  12.7
# 2017-08-23  11.4
#
# [365 rows x 8 columns]

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
max_prcp = 
min_prcp =
mean_prcp =

# %%
session.close()

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number stations in the dataset
st_count = session.query(Station).group_by(Station.station)
# print(len(st_count))
for row in st_count:
    print(f"id: {row.id}, station: {row.station}, name: {row.name}")
print(f"Total number of stations: {st_count.count()}")
# Out:
# id: 7, station: USC00511918, name: HONOLULU OBSERVATORY 702.2, HI US
# id: 1, station: USC00513117, name: KANEOHE 838.1, HI US
# id: 2, station: USC00514830, name: KUALOA RANCH HEADQUARTERS 886.9, HI US
# id: 8, station: USC00516128, name: MANOA LYON ARBO 785.2, HI US
# id: 3, station: USC00517948, name: PEARL CITY, HI US
# id: 4, station: USC00518838, name: UPPER WAHIAWA 874.3, HI US
# id: 6, station: USC00519281, name: WAIHEE 837.5, HI US
# id: 0, station: USC00519397, name: WAIKIKI 717.2, HI US
# id: 5, station: USC00519523, name: WAIMANALO EXPERIMENTAL FARM, HI US
# Total number of stations: 9

# %%
session.close()

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# create measurement_df from Measurement table
measurement_df = pd.read_sql("SELECT * FROM Measurement", conn)
measurement_df
# Out:
#           id      station        date  prcp  tobs
# 0          0  USC00519397  2010-01-01   2.0  18.3
# 1          1  USC00519397  2010-01-02   0.0  17.2
# 2          2  USC00519397  2010-01-03   0.0  23.3
# 3          3  USC00519397  2010-01-04   0.0  24.4
# 4          4  USC00519397  2010-01-06   NaN  22.8
# ...      ...          ...         ...   ...   ...
# 19545  19545  USC00516128  2017-08-19   2.3  21.7
# 19546  19546  USC00516128  2017-08-20   NaN  25.6
# 19547  19547  USC00516128  2017-08-21  14.2  24.4
# 19548  19548  USC00516128  2017-08-22  12.7  24.4
# 19549  19549  USC00516128  2017-08-23  11.4  24.4
#
# [19550 rows x 5 columns]

# %%
# create station_df from Station table
station_df = pd.read_sql("SELECT * FROM Station", conn)
station_df
# Out:
#    id      station                                    name  latitude  \
# 0   0  USC00519397                    WAIKIKI 717.2, HI US  21.27160
# 1   1  USC00513117                    KANEOHE 838.1, HI US  21.42340
# 2   2  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130
# 3   3  USC00517948                       PEARL CITY, HI US  21.39340
# 4   4  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920
# 5   5  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556
# 6   6  USC00519281                     WAIHEE 837.5, HI US  21.45167
# 7   7  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520
# 8   8  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310
#
#    longitude  elevation
# 0 -157.81680      0.914
# 1 -157.80150      4.450
# 2 -157.83740      2.133
# 3 -157.97510      3.627
# 4 -158.01110     93.447
# 5 -157.71139      5.943
# 6 -157.84889     10.027
# 7 -157.99920      0.274
# 8 -157.80250     46.449

# %%
# Merge measurement_df and station_df to create df
df = pd.merge(station_df, measurement_df, on="station")
df
# Out:
#        id_x      station                          name  latitude  longitude  \
# 0         0  USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 1         0  USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 2         0  USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 3         0  USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# 4         0  USC00519397          WAIKIKI 717.2, HI US   21.2716  -157.8168
# ...     ...          ...                           ...       ...        ...
# 19545     8  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19546     8  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19547     8  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19548     8  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
# 19549     8  USC00516128  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025
#
#        elevation   id_y        date  prcp  tobs
# 0          0.914      0  2010-01-01   2.0  18.3
# 1          0.914      1  2010-01-02   0.0  17.2
# 2          0.914      2  2010-01-03   0.0  23.3
# 3          0.914      3  2010-01-04   0.0  24.4
# 4          0.914      4  2010-01-06   NaN  22.8
# ...          ...    ...         ...   ...   ...
# 19545     46.449  19545  2017-08-19   2.3  21.7
# 19546     46.449  19546  2017-08-20   NaN  25.6
# 19547     46.449  19547  2017-08-21  14.2  24.4
# 19548     46.449  19548  2017-08-22  12.7  24.4
# 19549     46.449  19549  2017-08-23  11.4  24.4
#
# [19550 rows x 10 columns]

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
gr_df = df.groupby('station').count()
gr_df = gr_df.sort_values('id_x', ascending=False)
gr_df = gr_df.reset_index()
gr_df
# Out:
#        station  id_x  name  latitude  longitude  elevation  id_y  date  prcp  \
# 0  USC00519281  2772  2772      2772       2772       2772  2772  2772  2772
# 1  USC00519397  2724  2724      2724       2724       2724  2724  2724  2685
# 2  USC00513117  2709  2709      2709       2709       2709  2709  2709  2696
# 3  USC00519523  2669  2669      2669       2669       2669  2669  2669  2572
# 4  USC00516128  2612  2612      2612       2612       2612  2612  2612  2484
# 5  USC00514830  2202  2202      2202       2202       2202  2202  2202  1937
# 6  USC00511918  1979  1979      1979       1979       1979  1979  1979  1932
# 7  USC00517948  1372  1372      1372       1372       1372  1372  1372   683
# 8  USC00518838   511   511       511        511        511   511   511   342
#
#    tobs
# 0  2772
# 1  2724
# 2  2709
# 3  2669
# 4  2612
# 5  2202
# 6  1979
# 7  1372
# 8   511

# %%
# List the stations and the counts in descending order.
for i in gr_df.index:
    print(gr_df['station'][i], gr_df['id_x'][i])
# Out:
# USC00519281 2772
# USC00519397 2724
# USC00513117 2709
# USC00519523 2669
# USC00516128 2612
# USC00514830 2202
# USC00511918 1979
# USC00517948 1372
# USC00518838 511

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
# Create active_df for most active station
active_df = df.loc[df['station']== 'USC00519281',:]
active_df
# Out:
#        id_x      station                 name  latitude  longitude  elevation  \
# 12187     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 12188     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 12189     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 12190     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 12191     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# ...     ...          ...                  ...       ...        ...        ...
# 14954     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 14955     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 14956     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 14957     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
# 14958     6  USC00519281  WAIHEE 837.5, HI US  21.45167 -157.84889     10.027
#
#         id_y        date  prcp  tobs
# 12187  12187  2010-01-01   3.8  21.1
# 12188  12188  2010-01-02   0.0  16.7
# 12189  12189  2010-01-03   0.0  23.3
# 12190  12190  2010-01-04   0.0  23.9
# 12191  12191  2010-01-05   0.0  23.3
# ...      ...         ...   ...   ...
# 14954  14954  2017-08-14   0.0  25.0
# 14955  14955  2017-08-15   8.1  25.0
# 14956  14956  2017-08-16   3.0  24.4
# 14957  14957  2017-08-17   0.3  24.4
# 14958  14958  2017-08-18   1.5  26.1
#
# [2772 rows x 10 columns]

# %%
# calculate the lowest, highest, and average temperature
lowest_temp = active_df['tobs'].min()
highest_temp = active_df['tobs'].max()
average_temp = active_df['tobs'].mean()
print(lowest_temp)
print(highest_temp)
print(average_temp)
# Out:
# 12.2
# 29.4
# 22.035822510822513

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
# get latest date for this station
latest_date = active_df['date'].max()
print(f'Most recent date for station USC00519281: {latest_date}')
# Out:
# Most recent date for station USC00519281: 2017-08-18

# %%
# Query last 12 months of data for this station
active_12 = session.query(Measurement.date, Measurement.tobs).\
                  filter(Measurement.date > dt.datetime(2016, 8, 18)).filter(Measurement.station == "USC00519281").\
                    order_by(Measurement.date)

active12_rows = [{"Date": result[0], "Temperature Observation": result[1]} for result in active_12]
print(len(active12_rows))
active12_rows
# Out:
# 356
# [{'Date': '2016-08-19', 'Temperature Observation': 26.1},
#  {'Date': '2016-08-20', 'Temperature Observation': 27.2},
#  {'Date': '2016-08-21', 'Temperature Observation': 26.1},
#  {'Date': '2016-08-22', 'Temperature Observation': 25.6},
#  {'Date': '2016-08-23', 'Temperature Observation': 25.0},
#  {'Date': '2016-08-24', 'Temperature Observation': 25.0},
#  {'Date': '2016-08-25', 'Temperature Observation': 26.7},
#  {'Date': '2016-08-26', 'Temperature Observation': 26.7},
#  {'Date': '2016-08-27', 'Temperature Observation': 23.9},
#  {'Date': '2016-08-28', 'Temperature Observation': 22.8},
#  {'Date': '2016-08-29', 'Temperature Observation': 25.6},
#  {'Date': '2016-08-30', 'Temperature Observation': 25.0},
#  {'Date': '2016-08-31', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-01', 'Temperature Observation': 26.7},
#  {'Date': '2016-09-02', 'Temperature Observation': 26.7},
#  {'Date': '2016-09-03', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-04', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-05', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-06', 'Temperature Observation': 22.8},
#  {'Date': '2016-09-07', 'Temperature Observation': 23.3},
#  {'Date': '2016-09-08', 'Temperature Observation': 26.7},
#  {'Date': '2016-09-09', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-10', 'Temperature Observation': 25.0},
#  {'Date': '2016-09-11', 'Temperature Observation': 26.7},
#  {'Date': '2016-09-12', 'Temperature Observation': 24.4},
#  {'Date': '2016-09-13', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-14', 'Temperature Observation': 23.9},
#  {'Date': '2016-09-15', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-16', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-17', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-18', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-19', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-20', 'Temperature Observation': 24.4},
#  {'Date': '2016-09-21', 'Temperature Observation': 23.3},
#  {'Date': '2016-09-22', 'Temperature Observation': 25.0},
#  {'Date': '2016-09-23', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-24', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-25', 'Temperature Observation': 26.1},
#  {'Date': '2016-09-26', 'Temperature Observation': 25.0},
#  {'Date': '2016-09-27', 'Temperature Observation': 26.7},
#  {'Date': '2016-09-28', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-29', 'Temperature Observation': 25.6},
#  {'Date': '2016-09-30', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-01', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-02', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-03', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-04', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-05', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-06', 'Temperature Observation': 23.9},
#  {'Date': '2016-10-07', 'Temperature Observation': 24.4},
#  {'Date': '2016-10-08', 'Temperature Observation': 22.8},
#  {'Date': '2016-10-09', 'Temperature Observation': 22.2},
#  {'Date': '2016-10-10', 'Temperature Observation': 21.7},
#  {'Date': '2016-10-11', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-12', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-13', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-14', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-15', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-16', 'Temperature Observation': 26.1},
#  {'Date': '2016-10-17', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-18', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-19', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-20', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-21', 'Temperature Observation': 25.6},
#  {'Date': '2016-10-22', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-23', 'Temperature Observation': 23.3},
#  {'Date': '2016-10-24', 'Temperature Observation': 23.9},
#  {'Date': '2016-10-25', 'Temperature Observation': 24.4},
#  {'Date': '2016-10-26', 'Temperature Observation': 22.8},
#  {'Date': '2016-10-27', 'Temperature Observation': 24.4},
#  {'Date': '2016-10-28', 'Temperature Observation': 23.3},
#  {'Date': '2016-10-29', 'Temperature Observation': 25.0},
#  {'Date': '2016-10-30', 'Temperature Observation': 24.4},
#  {'Date': '2016-10-31', 'Temperature Observation': 24.4},
#  {'Date': '2016-11-01', 'Temperature Observation': 23.3},
#  {'Date': '2016-11-02', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-03', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-04', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-05', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-06', 'Temperature Observation': 21.7},
#  {'Date': '2016-11-07', 'Temperature Observation': 17.2},
#  {'Date': '2016-11-08', 'Temperature Observation': 21.1},
#  {'Date': '2016-11-09', 'Temperature Observation': 20.0},
#  {'Date': '2016-11-10', 'Temperature Observation': 19.4},
#  {'Date': '2016-11-11', 'Temperature Observation': 25.0},
#  {'Date': '2016-11-12', 'Temperature Observation': 23.3},
#  {'Date': '2016-11-13', 'Temperature Observation': 25.0},
#  {'Date': '2016-11-14', 'Temperature Observation': 24.4},
#  {'Date': '2016-11-15', 'Temperature Observation': 24.4},
#  {'Date': '2016-11-16', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-17', 'Temperature Observation': 24.4},
#  {'Date': '2016-11-18', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-19', 'Temperature Observation': 22.8},
#  {'Date': '2016-11-20', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-21', 'Temperature Observation': 22.8},
#  {'Date': '2016-11-22', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-23', 'Temperature Observation': 23.3},
#  {'Date': '2016-11-24', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-25', 'Temperature Observation': 23.3},
#  {'Date': '2016-11-26', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-27', 'Temperature Observation': 22.8},
#  {'Date': '2016-11-28', 'Temperature Observation': 23.9},
#  {'Date': '2016-11-29', 'Temperature Observation': 22.8},
#  {'Date': '2016-11-30', 'Temperature Observation': 22.8},
#  {'Date': '2016-12-01', 'Temperature Observation': 23.3},
#  {'Date': '2016-12-02', 'Temperature Observation': 21.1},
#  {'Date': '2016-12-03', 'Temperature Observation': 22.2},
#  {'Date': '2016-12-04', 'Temperature Observation': 21.1},
#  {'Date': '2016-12-05', 'Temperature Observation': 19.4},
#  {'Date': '2016-12-06', 'Temperature Observation': 19.4},
#  {'Date': '2016-12-07', 'Temperature Observation': 20.6},
#  {'Date': '2016-12-08', 'Temperature Observation': 21.1},
#  {'Date': '2016-12-09', 'Temperature Observation': 20.0},
#  {'Date': '2016-12-10', 'Temperature Observation': 20.6},
#  {'Date': '2016-12-11', 'Temperature Observation': 20.6},
#  {'Date': '2016-12-12', 'Temperature Observation': 18.9},
#  {'Date': '2016-12-13', 'Temperature Observation': 18.3},
#  {'Date': '2016-12-14', 'Temperature Observation': 20.0},
#  {'Date': '2016-12-15', 'Temperature Observation': 16.7},
#  {'Date': '2016-12-16', 'Temperature Observation': 23.9},
#  {'Date': '2016-12-17', 'Temperature Observation': 21.1},
#  {'Date': '2016-12-18', 'Temperature Observation': 20.6},
#  {'Date': '2016-12-19', 'Temperature Observation': 24.4},
#  {'Date': '2016-12-20', 'Temperature Observation': 24.4},
#  {'Date': '2016-12-21', 'Temperature Observation': 23.3},
#  {'Date': '2016-12-22', 'Temperature Observation': 22.8},
#  {'Date': '2016-12-23', 'Temperature Observation': 21.7},
#  {'Date': '2016-12-24', 'Temperature Observation': 23.3},
#  {'Date': '2016-12-25', 'Temperature Observation': 23.3},
#  {'Date': '2016-12-26', 'Temperature Observation': 22.2},
#  {'Date': '2016-12-27', 'Temperature Observation': 21.7},
#  {'Date': '2016-12-28', 'Temperature Observation': 22.2},
#  {'Date': '2016-12-29', 'Temperature Observation': 23.3},
#  {'Date': '2016-12-30', 'Temperature Observation': 20.6},
#  {'Date': '2016-12-31', 'Temperature Observation': 19.4},
#  {'Date': '2017-01-01', 'Temperature Observation': 22.2},
#  {'Date': '2017-01-02', 'Temperature Observation': 21.1},
#  {'Date': '2017-01-03', 'Temperature Observation': 17.8},
#  {'Date': '2017-01-04', 'Temperature Observation': 17.2},
#  {'Date': '2017-01-05', 'Temperature Observation': 17.2},
#  {'Date': '2017-01-06', 'Temperature Observation': 16.7},
#  {'Date': '2017-01-07', 'Temperature Observation': 21.1},
#  {'Date': '2017-01-08', 'Temperature Observation': 21.1},
#  {'Date': '2017-01-09', 'Temperature Observation': 16.7},
#  {'Date': '2017-01-10', 'Temperature Observation': 16.7},
#  {'Date': '2017-01-11', 'Temperature Observation': 17.2},
#  {'Date': '2017-01-12', 'Temperature Observation': 18.3},
#  {'Date': '2017-01-13', 'Temperature Observation': 20.6},
#  {'Date': '2017-01-14', 'Temperature Observation': 25.0},
#  {'Date': '2017-01-15', 'Temperature Observation': 21.1},
#  {'Date': '2017-01-16', 'Temperature Observation': 23.3},
#  {'Date': '2017-01-17', 'Temperature Observation': 20.6},
#  {'Date': '2017-01-18', 'Temperature Observation': 22.2},
#  {'Date': '2017-01-19', 'Temperature Observation': 21.7},
#  {'Date': '2017-01-20', 'Temperature Observation': 20.6},
#  {'Date': '2017-01-21', 'Temperature Observation': 21.7},
#  {'Date': '2017-01-22', 'Temperature Observation': 21.7},
#  {'Date': '2017-01-23', 'Temperature Observation': 22.2},
#  {'Date': '2017-01-24', 'Temperature Observation': 22.2},
#  {'Date': '2017-01-25', 'Temperature Observation': 20.6},
#  {'Date': '2017-01-26', 'Temperature Observation': 21.1},
#  {'Date': '2017-01-27', 'Temperature Observation': 18.9},
#  {'Date': '2017-01-28', 'Temperature Observation': 18.3},
#  {'Date': '2017-01-29', 'Temperature Observation': 20.6},
#  {'Date': '2017-01-30', 'Temperature Observation': 20.0},
#  {'Date': '2017-01-31', 'Temperature Observation': 20.0},
#  {'Date': '2017-02-01', 'Temperature Observation': 20.0},
#  {'Date': '2017-02-02', 'Temperature Observation': 15.0},
#  {'Date': '2017-02-03', 'Temperature Observation': 15.6},
#  {'Date': '2017-02-04', 'Temperature Observation': 21.1},
#  {'Date': '2017-02-05', 'Temperature Observation': 22.8},
#  {'Date': '2017-02-06', 'Temperature Observation': 23.9},
#  {'Date': '2017-02-07', 'Temperature Observation': 17.8},
#  {'Date': '2017-02-08', 'Temperature Observation': 15.0},
#  {'Date': '2017-02-09', 'Temperature Observation': 15.0},
#  {'Date': '2017-02-10', 'Temperature Observation': 16.7},
#  {'Date': '2017-02-11', 'Temperature Observation': 20.0},
#  {'Date': '2017-02-12', 'Temperature Observation': 21.1},
#  {'Date': '2017-02-13', 'Temperature Observation': 22.8},
#  {'Date': '2017-02-14', 'Temperature Observation': 26.1},
#  {'Date': '2017-02-15', 'Temperature Observation': 23.9},
#  {'Date': '2017-02-16', 'Temperature Observation': 18.3},
#  {'Date': '2017-02-17', 'Temperature Observation': 21.1},
#  {'Date': '2017-02-18', 'Temperature Observation': 23.3},
#  {'Date': '2017-02-19', 'Temperature Observation': 21.1},
#  {'Date': '2017-02-20', 'Temperature Observation': 21.1},
#  {'Date': '2017-02-21', 'Temperature Observation': 21.7},
#  {'Date': '2017-02-22', 'Temperature Observation': 21.7},
#  {'Date': '2017-02-23', 'Temperature Observation': 21.7},
#  {'Date': '2017-02-24', 'Temperature Observation': 20.6},
#  {'Date': '2017-02-25', 'Temperature Observation': 16.1},
#  {'Date': '2017-02-26', 'Temperature Observation': 19.4},
#  {'Date': '2017-02-27', 'Temperature Observation': 18.3},
#  {'Date': '2017-02-28', 'Temperature Observation': 22.2},
#  {'Date': '2017-03-01', 'Temperature Observation': 21.7},
#  {'Date': '2017-03-02', 'Temperature Observation': 22.8},
#  {'Date': '2017-03-03', 'Temperature Observation': 22.2},
#  {'Date': '2017-03-04', 'Temperature Observation': 25.0},
#  {'Date': '2017-03-05', 'Temperature Observation': 22.8},
#  {'Date': '2017-03-06', 'Temperature Observation': 19.4},
#  {'Date': '2017-03-07', 'Temperature Observation': 16.7},
#  {'Date': '2017-03-08', 'Temperature Observation': 17.8},
#  {'Date': '2017-03-09', 'Temperature Observation': 19.4},
#  {'Date': '2017-03-10', 'Temperature Observation': 18.9},
#  {'Date': '2017-03-11', 'Temperature Observation': 27.2},
#  {'Date': '2017-03-12', 'Temperature Observation': 20.6},
#  {'Date': '2017-03-13', 'Temperature Observation': 18.9},
#  {'Date': '2017-03-14', 'Temperature Observation': 19.4},
#  {'Date': '2017-03-15', 'Temperature Observation': 20.6},
#  {'Date': '2017-03-16', 'Temperature Observation': 18.9},
#  {'Date': '2017-03-17', 'Temperature Observation': 20.0},
#  {'Date': '2017-03-18', 'Temperature Observation': 18.3},
#  {'Date': '2017-03-19', 'Temperature Observation': 23.3},
#  {'Date': '2017-03-20', 'Temperature Observation': 20.6},
#  {'Date': '2017-03-21', 'Temperature Observation': 22.2},
#  {'Date': '2017-03-22', 'Temperature Observation': 22.8},
#  {'Date': '2017-03-23', 'Temperature Observation': 22.2},
#  {'Date': '2017-03-24', 'Temperature Observation': 21.7},
#  {'Date': '2017-03-25', 'Temperature Observation': 24.4},
#  {'Date': '2017-03-26', 'Temperature Observation': 25.0},
#  {'Date': '2017-03-27', 'Temperature Observation': 24.4},
#  {'Date': '2017-03-28', 'Temperature Observation': 23.3},
#  {'Date': '2017-03-29', 'Temperature Observation': 20.0},
#  {'Date': '2017-03-30', 'Temperature Observation': 22.8},
#  {'Date': '2017-03-31', 'Temperature Observation': 21.7},
#  {'Date': '2017-04-01', 'Temperature Observation': 23.3},
#  {'Date': '2017-04-02', 'Temperature Observation': 23.9},
#  {'Date': '2017-04-03', 'Temperature Observation': 21.1},
#  {'Date': '2017-04-04', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-05', 'Temperature Observation': 21.7},
#  {'Date': '2017-04-06', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-07', 'Temperature Observation': 23.3},
#  {'Date': '2017-04-08', 'Temperature Observation': 25.0},
#  {'Date': '2017-04-09', 'Temperature Observation': 25.6},
#  {'Date': '2017-04-10', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-11', 'Temperature Observation': 21.1},
#  {'Date': '2017-04-12', 'Temperature Observation': 20.6},
#  {'Date': '2017-04-13', 'Temperature Observation': 20.6},
#  {'Date': '2017-04-14', 'Temperature Observation': 23.3},
#  {'Date': '2017-04-15', 'Temperature Observation': 25.6},
#  {'Date': '2017-04-16', 'Temperature Observation': 21.7},
#  {'Date': '2017-04-17', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-18', 'Temperature Observation': 20.0},
#  {'Date': '2017-04-19', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-20', 'Temperature Observation': 24.4},
#  {'Date': '2017-04-21', 'Temperature Observation': 20.6},
#  {'Date': '2017-04-22', 'Temperature Observation': 22.2},
#  {'Date': '2017-04-23', 'Temperature Observation': 24.4},
#  {'Date': '2017-04-24', 'Temperature Observation': 20.0},
#  {'Date': '2017-04-25', 'Temperature Observation': 22.2},
#  {'Date': '2017-04-26', 'Temperature Observation': 23.3},
#  {'Date': '2017-04-27', 'Temperature Observation': 21.1},
#  {'Date': '2017-04-28', 'Temperature Observation': 19.4},
#  {'Date': '2017-04-29', 'Temperature Observation': 22.2},
#  {'Date': '2017-04-30', 'Temperature Observation': 15.6},
#  {'Date': '2017-05-01', 'Temperature Observation': 18.3},
#  {'Date': '2017-05-02', 'Temperature Observation': 23.9},
#  {'Date': '2017-05-03', 'Temperature Observation': 21.1},
#  {'Date': '2017-05-04', 'Temperature Observation': 23.9},
#  {'Date': '2017-05-05', 'Temperature Observation': 21.1},
#  {'Date': '2017-05-06', 'Temperature Observation': 26.1},
#  {'Date': '2017-05-07', 'Temperature Observation': 23.9},
#  {'Date': '2017-05-08', 'Temperature Observation': 21.1},
#  {'Date': '2017-05-09', 'Temperature Observation': 19.4},
#  {'Date': '2017-05-10', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-11', 'Temperature Observation': 21.1},
#  {'Date': '2017-05-12', 'Temperature Observation': 23.9},
#  {'Date': '2017-05-13', 'Temperature Observation': 24.4},
#  {'Date': '2017-05-14', 'Temperature Observation': 25.0},
#  {'Date': '2017-05-15', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-16', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-17', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-18', 'Temperature Observation': 20.6},
#  {'Date': '2017-05-19', 'Temperature Observation': 20.0},
#  {'Date': '2017-05-20', 'Temperature Observation': 24.4},
#  {'Date': '2017-05-21', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-22', 'Temperature Observation': 21.7},
#  {'Date': '2017-05-23', 'Temperature Observation': 21.7},
#  {'Date': '2017-05-24', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-25', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-26', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-27', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-28', 'Temperature Observation': 26.7},
#  {'Date': '2017-05-29', 'Temperature Observation': 23.3},
#  {'Date': '2017-05-30', 'Temperature Observation': 22.2},
#  {'Date': '2017-05-31', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-01', 'Temperature Observation': 26.7},
#  {'Date': '2017-06-02', 'Temperature Observation': 24.4},
#  {'Date': '2017-06-03', 'Temperature Observation': 24.4},
#  {'Date': '2017-06-04', 'Temperature Observation': 25.0},
#  {'Date': '2017-06-05', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-06', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-07', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-08', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-09', 'Temperature Observation': 22.2},
#  {'Date': '2017-06-10', 'Temperature Observation': 23.3},
#  {'Date': '2017-06-11', 'Temperature Observation': 23.3},
#  {'Date': '2017-06-12', 'Temperature Observation': 23.3},
#  {'Date': '2017-06-13', 'Temperature Observation': 24.4},
#  {'Date': '2017-06-14', 'Temperature Observation': 23.3},
#  {'Date': '2017-06-15', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-16', 'Temperature Observation': 22.8},
#  {'Date': '2017-06-17', 'Temperature Observation': 26.1},
#  {'Date': '2017-06-18', 'Temperature Observation': 23.9},
#  {'Date': '2017-06-19', 'Temperature Observation': 22.2},
#  {'Date': '2017-06-20', 'Temperature Observation': 22.2},
#  {'Date': '2017-06-21', 'Temperature Observation': 23.3},
#  {'Date': '2017-06-22', 'Temperature Observation': 22.2},
#  {'Date': '2017-06-23', 'Temperature Observation': 22.2},
#  {'Date': '2017-06-24', 'Temperature Observation': 25.0},
#  {'Date': '2017-06-25', 'Temperature Observation': 21.7},
#  {'Date': '2017-06-26', 'Temperature Observation': 22.8},
#  {'Date': '2017-06-27', 'Temperature Observation': 24.4},
#  {'Date': '2017-06-28', 'Temperature Observation': 25.0},
#  {'Date': '2017-06-29', 'Temperature Observation': 24.4},
#  {'Date': '2017-06-30', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-01', 'Temperature Observation': 26.1},
#  {'Date': '2017-07-02', 'Temperature Observation': 27.2},
#  {'Date': '2017-07-03', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-04', 'Temperature Observation': 25.6},
#  {'Date': '2017-07-05', 'Temperature Observation': 25.0},
#  {'Date': '2017-07-06', 'Temperature Observation': 23.3},
#  {'Date': '2017-07-07', 'Temperature Observation': 23.9},
#  {'Date': '2017-07-08', 'Temperature Observation': 25.6},
#  {'Date': '2017-07-09', 'Temperature Observation': 25.6},
#  {'Date': '2017-07-10', 'Temperature Observation': 20.6},
#  {'Date': '2017-07-11', 'Temperature Observation': 22.2},
#  {'Date': '2017-07-12', 'Temperature Observation': 23.3},
#  {'Date': '2017-07-13', 'Temperature Observation': 23.3},
#  {'Date': '2017-07-14', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-15', 'Temperature Observation': 26.7},
#  {'Date': '2017-07-16', 'Temperature Observation': 26.7},
#  {'Date': '2017-07-17', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-18', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-19', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-20', 'Temperature Observation': 25.0},
#  {'Date': '2017-07-21', 'Temperature Observation': 25.0},
#  {'Date': '2017-07-22', 'Temperature Observation': 25.0},
#  {'Date': '2017-07-23', 'Temperature Observation': 27.8},
#  {'Date': '2017-07-24', 'Temperature Observation': 23.9},
#  {'Date': '2017-07-25', 'Temperature Observation': 25.0},
#  {'Date': '2017-07-26', 'Temperature Observation': 23.9},
#  {'Date': '2017-07-27', 'Temperature Observation': 24.4},
#  {'Date': '2017-07-28', 'Temperature Observation': 27.2},
#  {'Date': '2017-07-29', 'Temperature Observation': 27.8},
#  {'Date': '2017-07-30', 'Temperature Observation': 27.2},
#  {'Date': '2017-07-31', 'Temperature Observation': 24.4},
#  {'Date': '2017-08-04', 'Temperature Observation': 25.0},
#  {'Date': '2017-08-05', 'Temperature Observation': 27.8},
#  {'Date': '2017-08-06', 'Temperature Observation': 28.3},
#  {'Date': '2017-08-13', 'Temperature Observation': 25.0},
#  {'Date': '2017-08-14', 'Temperature Observation': 25.0},
#  {'Date': '2017-08-15', 'Temperature Observation': 25.0},
#  {'Date': '2017-08-16', 'Temperature Observation': 24.4},
#  {'Date': '2017-08-17', 'Temperature Observation': 24.4},
#  {'Date': '2017-08-18', 'Temperature Observation': 26.1}]

# %%
# plot the results as a histogram
plot_df = pd.DataFrame(active12_rows)
ax = plot_df.hist(column=["Temperature Observation"], bins=12, grid=True)
plt.tight_layout()

# %%
h = plt.hist(plot_df['Temperature Observation'], bins=12)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
